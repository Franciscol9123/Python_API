# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 582

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 2 of Set 1 | isafjordur
# Processing Record 3 of Set 1 | utrik
# Processing Record 4 of Set 1 | mount isa
# Processing Record 5 of Set 1 | chui
# Processing Record 6 of Set 1 | sandnessjoen
# Processing Record 7 of Set 1 | dudinka
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | tommot
# Processing Record 10 of Set 1 | lakatoro
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mokhsogollokh
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | sinabang
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | kuqa
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | novyy urengoy
# Processing Record 21 of Set 1 | tafresh
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | selma
# Processing Record 24 of Set 1 | zhicheng
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | taksimo
# Processing Record 27 of Set 1 | zemio
# Processing Record 28 of Set 1 | namibe
# Processing Record 29 of Set 1 | edinburgh of the seven seas
# Processing Record 30 of Set 1 | saint-louis
# Processing Record 31 of Set 1 | blackmans bay
# Processing Record 32 of Set 1 | nogliki
# Processing Record 33 of Set 1 | ust-nera
# Processing Record 34 of Set 1 | islamkot
# Processing Record 35 of Set 1 | stanley
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | al bawiti
# Processing Record 40 of Set 1 | mananara
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | west island
# Processing Record 43 of Set 1 | sirsa
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | leava
# Processing Record 46 of Set 1 | anadyr
# Processing Record 47 of Set 1 | pohang
# Processing Record 48 of Set 1 | sena madureira
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | polyarnyy
# Processing Record 0 of Set 2 | namie
# Processing Record 1 of Set 2 | obubra
# Processing Record 2 of Set 2 | victorica
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | khovd
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 2 | grytviken
# Processing Record 8 of Set 2 | port mathurin
# Processing Record 9 of Set 2 | zaozersk
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | puerto natales
# Processing Record 13 of Set 2 | adamstown
# Processing Record 14 of Set 2 | sainte-anne-des-monts
# Processing Record 15 of Set 2 | naze
# Processing Record 16 of Set 2 | aasiaat
# Processing Record 17 of Set 2 | brisas de zicatela
# Processing Record 18 of Set 2 | madimba
# Processing Record 19 of Set 2 | weno
# Processing Record 20 of Set 2 | puerto vilelas
# Processing Record 21 of Set 2 | gbadolite
# Processing Record 22 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 23 of Set 2 | cartagena
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | grand gaube
# Processing Record 26 of Set 2 | opuwo
# Processing Record 27 of Set 2 | neftekamsk
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | pokaran
# Processing Record 30 of Set 2 | kapa'a
# Processing Record 31 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 2 | north shore
# Processing Record 33 of Set 2 | valenca do piaui
# Processing Record 34 of Set 2 | howrah
# Processing Record 35 of Set 2 | invercargill
# Processing Record 36 of Set 2 | wynyard
# Processing Record 37 of Set 2 | orangeburg
# Processing Record 38 of Set 2 | baoding
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | robertsport
# Processing Record 41 of Set 2 | labytnangi
# Processing Record 42 of Set 2 | juan griego
# Processing Record 43 of Set 2 | hawaiian paradise park
# Processing Record 44 of Set 2 | puerto baquerizo moreno
# Processing Record 45 of Set 2 | wailua homesteads
# Processing Record 46 of Set 2 | scarborough
# Processing Record 47 of Set 2 | rio do sul
# Processing Record 48 of Set 2 | fort st. john
# Processing Record 49 of Set 2 | albany
# Processing Record 0 of Set 3 | antsiranana
# Processing Record 1 of Set 3 | nar'yan-mar
# Processing Record 2 of Set 3 | whitehorse
# Processing Record 3 of Set 3 | nuuk
# Processing Record 4 of Set 3 | vorkuta
# Processing Record 5 of Set 3 | nizhneudinsk
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | palikir - national government center
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | qaqortoq
# Processing Record 12 of Set 3 | turpan
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | shihezi
# Processing Record 15 of Set 3 | culiacan
# Processing Record 16 of Set 3 | jindrichuv hradec
# Processing Record 17 of Set 3 | cootamundra
# Processing Record 18 of Set 3 | olonkinbyen
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | badger
# Processing Record 21 of Set 3 | remire-montjoly
# Processing Record 22 of Set 3 | happy valley-goose bay
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | dumai
# Processing Record 25 of Set 3 | broken hill
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | udachny
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | college
# Processing Record 30 of Set 3 | otofuke
# Processing Record 31 of Set 3 | ketchikan
# Processing Record 32 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 33 of Set 3 | yakeshi
# Processing Record 34 of Set 3 | peniche
# Processing Record 35 of Set 3 | filadelfia
# Processing Record 36 of Set 3 | lihue
# Processing Record 37 of Set 3 | rabo de peixe
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | guerrero negro
# Processing Record 40 of Set 3 | selfoss
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | ashland
# Processing Record 43 of Set 3 | horta
# Processing Record 44 of Set 3 | eraan
# Processing Record 45 of Set 3 | okhtyrka
# Processing Record 46 of Set 3 | saipan
# Processing Record 47 of Set 3 | tazacorte
# Processing Record 48 of Set 3 | minas de marcona
# Processing Record 49 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 0 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 4 | tazovsky
# Processing Record 2 of Set 4 | lautoka
# Processing Record 3 of Set 4 | kazan
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | jose panganiban
# Processing Record 6 of Set 4 | amvrosiyivka
# Processing Record 7 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 4 | al quwayrah
# Processing Record 9 of Set 4 | isla mujeres
# Processing Record 10 of Set 4 | rohru
# Processing Record 11 of Set 4 | rikaze
# Processing Record 12 of Set 4 | machico
# Processing Record 13 of Set 4 | klyuchi
# Processing Record 14 of Set 4 | polevskoy
# Processing Record 15 of Set 4 | lyantor
# Processing Record 16 of Set 4 | arkhangel'sk
# Processing Record 17 of Set 4 | altay
# Processing Record 18 of Set 4 | florenville
# Processing Record 19 of Set 4 | plaza huincul
# Processing Record 20 of Set 4 | turbat
# Processing Record 21 of Set 4 | vilyuysk
# Processing Record 22 of Set 4 | kristiansund
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | bozeman
# Processing Record 25 of Set 4 | fort bragg
# Processing Record 26 of Set 4 | kingston
# Processing Record 27 of Set 4 | bubaque
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | midvagur
# Processing Record 30 of Set 4 | okhotsk
# Processing Record 31 of Set 4 | el idrissia
# Processing Record 32 of Set 4 | antsohihy
# Processing Record 33 of Set 4 | katabu
# Processing Record 34 of Set 4 | afaahiti
# Processing Record 35 of Set 4 | nadi
# Processing Record 36 of Set 4 | xilin hot
# Processing Record 37 of Set 4 | usinsk
# Processing Record 38 of Set 4 | papatowai
# Processing Record 39 of Set 4 | zaragoza
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | serhetabat
# Processing Record 42 of Set 4 | mount pearl
# Processing Record 43 of Set 4 | el granada
# Processing Record 44 of Set 4 | deqen
# Processing Record 45 of Set 4 | muynoq
# Processing Record 46 of Set 4 | ta`u
# Processing Record 47 of Set 4 | janakpur
# Processing Record 48 of Set 4 | shushtar
# Processing Record 49 of Set 4 | banda aceh
# Processing Record 0 of Set 5 | mersa matruh
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | nadvoitsy
# Processing Record 3 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 4 of Set 5 | margaret river
# Processing Record 5 of Set 5 | masuguru
# Processing Record 6 of Set 5 | jayapura
# Processing Record 7 of Set 5 | jaumave
# Processing Record 8 of Set 5 | poshekhon'ye
# Processing Record 9 of Set 5 | kotel'nich
# Processing Record 10 of Set 5 | san felipe
# Processing Record 11 of Set 5 | st. john's
# Processing Record 12 of Set 5 | ixtapa
# Processing Record 13 of Set 5 | ascension
# Processing Record 14 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 5 | howard springs
# Processing Record 16 of Set 5 | garachico
# Processing Record 17 of Set 5 | jefferson city
# Processing Record 18 of Set 5 | itoigawa
# Processing Record 19 of Set 5 | ishigaki
# Processing Record 20 of Set 5 | luau
# Processing Record 21 of Set 5 | hermanus
# Processing Record 22 of Set 5 | kone
# Processing Record 23 of Set 5 | ancud
# Processing Record 24 of Set 5 | azul
# Processing Record 25 of Set 5 | punta arenas
# Processing Record 26 of Set 5 | tughyl
# Processing Record 27 of Set 5 | sorong
# Processing Record 28 of Set 5 | yuzhno-kurilsk
# Processing Record 29 of Set 5 | la'ie
# Processing Record 30 of Set 5 | keflavik
# Processing Record 31 of Set 5 | egilsstadir
# Processing Record 32 of Set 5 | nigel
# Processing Record 33 of Set 5 | atafu village
# Processing Record 34 of Set 5 | vorgashor
# Processing Record 35 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 36 of Set 5 | lebu
# Processing Record 37 of Set 5 | qarawul
# Processing Record 38 of Set 5 | constantia
# Processing Record 39 of Set 5 | juhaynah
# Processing Record 40 of Set 5 | alotau
# Processing Record 41 of Set 5 | maceio
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | fale old settlement
# Processing Record 44 of Set 5 | mountain home
# Processing Record 45 of Set 5 | vernon
# Processing Record 46 of Set 5 | zhengzhou
# Processing Record 47 of Set 5 | sakakah
# Processing Record 48 of Set 5 | quang ngai
# Processing Record 49 of Set 5 | butterworth
# Processing Record 0 of Set 6 | penne
# Processing Record 1 of Set 6 | kiunga
# Processing Record 2 of Set 6 | abadiania
# Processing Record 3 of Set 6 | dampit
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | crane
# Processing Record 6 of Set 6 | bikenibeu village
# Processing Record 7 of Set 6 | new norfolk
# Processing Record 8 of Set 6 | newman
# Processing Record 9 of Set 6 | moramanga
# Processing Record 10 of Set 6 | el alto
# Processing Record 11 of Set 6 | saiki
# Processing Record 12 of Set 6 | khandyga
# Processing Record 13 of Set 6 | papao
# Processing Record 14 of Set 6 | itamaraca
# Processing Record 15 of Set 6 | uturoa
# Processing Record 16 of Set 6 | cova figueira
# Processing Record 17 of Set 6 | belomorsk
# Processing Record 18 of Set 6 | mejit
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | inari
# Processing Record 22 of Set 6 | nouadhibou
# Processing Record 23 of Set 6 | mammoth lakes
# Processing Record 24 of Set 6 | zahedan
# Processing Record 25 of Set 6 | pacific grove
# Processing Record 26 of Set 6 | hailar
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | christchurch
# Processing Record 29 of Set 6 | fang
# Processing Record 30 of Set 6 | port isabel
# Processing Record 31 of Set 6 | choibalsan
# Processing Record 32 of Set 6 | saudarkrokur
# Processing Record 33 of Set 6 | juneau
# Processing Record 34 of Set 6 | saint-joseph
# Processing Record 35 of Set 6 | hauterive
# Processing Record 36 of Set 6 | zhoucheng
# Processing Record 37 of Set 6 | tobelo
# Processing Record 38 of Set 6 | bhalwal
# Processing Record 39 of Set 6 | koyulhisar
# Processing Record 40 of Set 6 | panjakent
# Processing Record 41 of Set 6 | santa quiteria
# Processing Record 42 of Set 6 | vilyuchinsk
# Processing Record 43 of Set 6 | holualoa
# Processing Record 44 of Set 6 | gadzhiyevo
# Processing Record 45 of Set 6 | limassol
# Processing Record 46 of Set 6 | malango
# Processing Record 47 of Set 6 | kitgum
# Processing Record 48 of Set 6 | san antonio de pale
# Processing Record 49 of Set 6 | hithadhoo
# Processing Record 0 of Set 7 | bardai
# Processing Record 1 of Set 7 | two rivers
# Processing Record 2 of Set 7 | northam
# Processing Record 3 of Set 7 | luderitz
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | manacapuru
# Processing Record 6 of Set 7 | kusong
# Processing Record 7 of Set 7 | yarmouth
# Processing Record 8 of Set 7 | bel ombre
# Processing Record 9 of Set 7 | bokovskaya
# Processing Record 10 of Set 7 | iskateley
# Processing Record 11 of Set 7 | port saint john's
# Processing Record 12 of Set 7 | fortaleza
# Processing Record 13 of Set 7 | la asuncion
# Processing Record 14 of Set 7 | alaghsas
# Processing Record 15 of Set 7 | ts'q'alt'ubo
# Processing Record 16 of Set 7 | alindao
# Processing Record 17 of Set 7 | muli
# Processing Record 18 of Set 7 | lompoc
# Processing Record 19 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 20 of Set 7 | watsa
# Processing Record 21 of Set 7 | camayenne
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | jackson
# Processing Record 25 of Set 7 | tandalti
# Processing Record 26 of Set 7 | starkville
# Processing Record 27 of Set 7 | ocean pointe
# City not found. Skipping...
# Processing Record 28 of Set 7 | east london
# Processing Record 29 of Set 7 | san clemente
# Processing Record 30 of Set 7 | pontes e lacerda
# Processing Record 31 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 32 of Set 7 | las tablas
# Processing Record 33 of Set 7 | amble
# Processing Record 34 of Set 7 | concepcion
# Processing Record 35 of Set 7 | turkmenbasy
# Processing Record 36 of Set 7 | bairnsdale
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | kismayo
# Processing Record 39 of Set 7 | carmo do paranaiba
# Processing Record 40 of Set 7 | anqing
# Processing Record 41 of Set 7 | reggane
# Processing Record 42 of Set 7 | flying fish cove
# Processing Record 43 of Set 7 | bamboo flat
# Processing Record 44 of Set 7 | cromer
# Processing Record 45 of Set 7 | mondariz
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | alipur
# Processing Record 48 of Set 7 | ardmore
# Processing Record 49 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 0 of Set 8 | diano marina
# Processing Record 1 of Set 8 | auki
# Processing Record 2 of Set 8 | taibet
# Processing Record 3 of Set 8 | undurkhaan
# Processing Record 4 of Set 8 | pandan
# Processing Record 5 of Set 8 | portland
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 8 of Set 8 | sao luis de montes belos
# Processing Record 9 of Set 8 | baley
# Processing Record 10 of Set 8 | whitby
# Processing Record 11 of Set 8 | cannonvale
# Processing Record 12 of Set 8 | valparaiso
# Processing Record 13 of Set 8 | fort mcmurray
# Processing Record 14 of Set 8 | bennett springs
# Processing Record 15 of Set 8 | benguela
# Processing Record 16 of Set 8 | santa cruz
# Processing Record 17 of Set 8 | al kharijah
# Processing Record 18 of Set 8 | kapuskasing
# Processing Record 19 of Set 8 | chonchi
# Processing Record 20 of Set 8 | masterton
# Processing Record 21 of Set 8 | lianshan
# Processing Record 22 of Set 8 | litayan
# Processing Record 23 of Set 8 | severo-yeniseyskiy
# Processing Record 24 of Set 8 | saint-philippe
# Processing Record 25 of Set 8 | goundam
# Processing Record 26 of Set 8 | kingscliff
# Processing Record 27 of Set 8 | nuku'alofa
# Processing Record 28 of Set 8 | fayzabad
# Processing Record 29 of Set 8 | bazarak
# Processing Record 30 of Set 8 | fallon
# Processing Record 31 of Set 8 | faya-largeau
# Processing Record 32 of Set 8 | labrador city
# Processing Record 33 of Set 8 | baiyin
# Processing Record 34 of Set 8 | takestan
# Processing Record 35 of Set 8 | vadso
# Processing Record 36 of Set 8 | chicoana
# Processing Record 37 of Set 8 | waingapu
# Processing Record 38 of Set 8 | bulgan
# Processing Record 39 of Set 8 | la passe
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | tambura
# Processing Record 42 of Set 8 | al jawf
# Processing Record 43 of Set 8 | loshnitsa
# Processing Record 44 of Set 8 | arar
# Processing Record 45 of Set 8 | tuzha
# Processing Record 46 of Set 8 | koryazhma
# Processing Record 47 of Set 8 | grand falls-windsor
# Processing Record 48 of Set 8 | usogorsk
# Processing Record 49 of Set 8 | myitkyina
# Processing Record 0 of Set 9 | manokwari
# Processing Record 1 of Set 9 | lake city
# Processing Record 2 of Set 9 | i-n-salah
# Processing Record 3 of Set 9 | kerikeri
# Processing Record 4 of Set 9 | enewetak
# Processing Record 5 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | mikomeseng
# Processing Record 7 of Set 9 | palora
# Processing Record 8 of Set 9 | salinopolis
# Processing Record 9 of Set 9 | igarka
# Processing Record 10 of Set 9 | yaren
# Processing Record 11 of Set 9 | valdivia
# Processing Record 12 of Set 9 | miyanoura
# City not found. Skipping...
# Processing Record 13 of Set 9 | andergrove
# Processing Record 14 of Set 9 | mahabe
# City not found. Skipping...
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | san fernando
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | nova sintra
# Processing Record 19 of Set 9 | farah
# Processing Record 20 of Set 9 | baiti
# Processing Record 21 of Set 9 | tanki leendert
# City not found. Skipping...
# Processing Record 22 of Set 9 | lushun
# Processing Record 23 of Set 9 | manado
# Processing Record 24 of Set 9 | suva
# Processing Record 25 of Set 9 | baluntaicun
# City not found. Skipping...
# Processing Record 26 of Set 9 | vila do maio
# Processing Record 27 of Set 9 | adligenswil
# Processing Record 28 of Set 9 | mwatate
# Processing Record 29 of Set 9 | magadan
# Processing Record 30 of Set 9 | nanga eboko
# Processing Record 31 of Set 9 | bom jardim
# Processing Record 32 of Set 9 | sao vicente
# Processing Record 33 of Set 9 | kulebaki
# Processing Record 34 of Set 9 | port douglas
# Processing Record 35 of Set 9 | colares
# Processing Record 36 of Set 9 | pasni
# Processing Record 37 of Set 9 | pocone
# Processing Record 38 of Set 9 | tandil
# Processing Record 39 of Set 9 | kill devil hills
# Processing Record 40 of Set 9 | rosoman
# Processing Record 41 of Set 9 | tongouson
# Processing Record 42 of Set 9 | camaqua
# Processing Record 43 of Set 9 | sumbawa besar
# Processing Record 44 of Set 9 | barra de santo antonio
# Processing Record 45 of Set 9 | kyzyl
# Processing Record 46 of Set 9 | vigan
# Processing Record 47 of Set 9 | san fernando de apure
# Processing Record 48 of Set 9 | callao
# Processing Record 49 of Set 9 | thunder bay
# Processing Record 0 of Set 10 | amga
# Processing Record 1 of Set 10 | kuala tungkal
# Processing Record 2 of Set 10 | presidente venceslau
# Processing Record 3 of Set 10 | solwezi
# Processing Record 4 of Set 10 | susuman
# Processing Record 5 of Set 10 | jincheng
# Processing Record 6 of Set 10 | pirallahi
# Processing Record 7 of Set 10 | ciudad constitucion
# Processing Record 8 of Set 10 | floro
# Processing Record 9 of Set 10 | marka
# Processing Record 10 of Set 10 | archangelos
# Processing Record 11 of Set 10 | elkins
# Processing Record 12 of Set 10 | bodaybo
# Processing Record 13 of Set 10 | juye
# Processing Record 14 of Set 10 | ambon
# Processing Record 15 of Set 10 | salekhard
# Processing Record 16 of Set 10 | canutama
# Processing Record 17 of Set 10 | tetiiv
# Processing Record 18 of Set 10 | karratha
# Processing Record 19 of Set 10 | monte argentario
# Processing Record 20 of Set 10 | santa rosa
# Processing Record 21 of Set 10 | san juan
# Processing Record 22 of Set 10 | esmeralda
# Processing Record 23 of Set 10 | sao miguel do araguaia
# Processing Record 24 of Set 10 | babolsar
# Processing Record 25 of Set 10 | shamakhi
# Processing Record 26 of Set 10 | thurso
# Processing Record 27 of Set 10 | colonia
# Processing Record 28 of Set 10 | shetpe
# Processing Record 29 of Set 10 | jorpeland
# Processing Record 30 of Set 10 | elliot lake
# Processing Record 31 of Set 10 | mili
# Processing Record 32 of Set 10 | revda
# Processing Record 33 of Set 10 | alofi
# Processing Record 34 of Set 10 | ribeira brava
# Processing Record 35 of Set 10 | lata
# Processing Record 36 of Set 10 | quartu sant'elena
# Processing Record 37 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 38 of Set 10 | richards bay
# Processing Record 39 of Set 10 | tolanaro
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | belmonte
# Processing Record 42 of Set 10 | bodo
# Processing Record 43 of Set 10 | guymon
# Processing Record 44 of Set 10 | timimoun
# Processing Record 45 of Set 10 | fray luis beltran
# Processing Record 46 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 10 | belyy yar
# Processing Record 48 of Set 10 | genlis
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 0 of Set 11 | nasir
# Processing Record 1 of Set 11 | glowno
# Processing Record 2 of Set 11 | pampierstad
# Processing Record 3 of Set 11 | dalandzadgad
# Processing Record 4 of Set 11 | megion
# Processing Record 5 of Set 11 | bonthe
# Processing Record 6 of Set 11 | mezhdurechenskiy
# Processing Record 7 of Set 11 | cold lake
# Processing Record 8 of Set 11 | bougouni
# Processing Record 9 of Set 11 | paphos
# Processing Record 10 of Set 11 | chengde
# Processing Record 11 of Set 11 | odessa
# Processing Record 12 of Set 11 | gediz
# Processing Record 13 of Set 11 | timbuktu
# Processing Record 14 of Set 11 | tinogasta
# Processing Record 15 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 16 of Set 11 | eastham
# Processing Record 17 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 18 of Set 11 | nova vicosa
# Processing Record 19 of Set 11 | las palmas
# Processing Record 20 of Set 11 | ulladulla
# Processing Record 21 of Set 11 | ola
# Processing Record 22 of Set 11 | tanumah
# Processing Record 23 of Set 11 | hadibu
# Processing Record 24 of Set 11 | rio grande
# Processing Record 25 of Set 11 | hajin
# Processing Record 26 of Set 11 | alo
# Processing Record 27 of Set 11 | kovdor
# Processing Record 28 of Set 11 | ostersund
# Processing Record 29 of Set 11 | noshiro
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | barbacoas
# Processing Record 32 of Set 11 | birobidzhan
# Processing Record 33 of Set 11 | nema
# Processing Record 34 of Set 11 | acapulco de juarez
# Processing Record 35 of Set 11 | prince rupert
# Processing Record 36 of Set 11 | gebeit
# Processing Record 37 of Set 11 | novodvinsk
# Processing Record 38 of Set 11 | puerto morazan
# Processing Record 39 of Set 11 | shanhaiguan
# Processing Record 40 of Set 11 | qapqal
# City not found. Skipping...
# Processing Record 41 of Set 11 | birao
# Processing Record 42 of Set 11 | oranjemund
# Processing Record 43 of Set 11 | tarnogskiy gorodok
# Processing Record 44 of Set 11 | ebon
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | talakan
# Processing Record 47 of Set 11 | mana
# Processing Record 48 of Set 11 | sao lourenco do sul
# Processing Record 49 of Set 11 | uromi
# Processing Record 0 of Set 12 | boca suno
# Processing Record 1 of Set 12 | muzayri'
# City not found. Skipping...
# Processing Record 2 of Set 12 | kincardine
# Processing Record 3 of Set 12 | ciudad lazaro cardenas
# Processing Record 4 of Set 12 | damongo
# City not found. Skipping...
# Processing Record 5 of Set 12 | tralee
# Processing Record 6 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 12 | santa luzia
# Processing Record 8 of Set 12 | maloye ganyushkino
# Processing Record 9 of Set 12 | margate
# Processing Record 10 of Set 12 | sungai raya
# Processing Record 11 of Set 12 | kievka
# Processing Record 12 of Set 12 | las khorey
# Processing Record 13 of Set 12 | mizan teferi
# Processing Record 14 of Set 12 | yemva
# Processing Record 15 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 16 of Set 12 | bethanie
# Processing Record 17 of Set 12 | plastun
# Processing Record 18 of Set 12 | aleksandrow lodzki
# Processing Record 19 of Set 12 | kutum
# Processing Record 20 of Set 12 | ingeniero guillermo n. juarez
# Processing Record 21 of Set 12 | dul'durga
# Processing Record 22 of Set 12 | koudougou
# Processing Record 23 of Set 12 | arthur's town
# City not found. Skipping...
# Processing Record 24 of Set 12 | karlskrona
# Processing Record 25 of Set 12 | tromso
# Processing Record 26 of Set 12 | saint joseph
# Processing Record 27 of Set 12 | shar
# Processing Record 28 of Set 12 | sillanwali
# Processing Record 29 of Set 12 | tra mhor
# Processing Record 30 of Set 12 | tantou
# Processing Record 31 of Set 12 | selebi-phikwe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    isafjordur  66.0755  -23.1240      6.61        87          97
# 1         utrik  11.2278  169.8474     28.10        78          18
# 2     mount isa -20.7333  139.5000     26.87        22           0
# 3          chui -33.6971  -53.4616      8.48        81          68
# 4  sandnessjoen  66.0217   12.6316     18.29        79          96
#
#    Wind Speed Country        Date
# 0        1.13      IS  1723089935
# 1        5.78      MH  1723089936
# 2        3.09      AU  1723089936
# 3        2.77      UY  1723089936
# 4        9.30      NO  1723089936

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          isafjordur  66.0755  -23.1240      6.61        87          97
# 1               utrik  11.2278  169.8474     28.10        78          18
# 2           mount isa -20.7333  139.5000     26.87        22           0
# 3                chui -33.6971  -53.4616      8.48        81          68
# 4        sandnessjoen  66.0217   12.6316     18.29        79          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.13      IS  1723089935
# 1              5.78      MH  1723089936
# 2              3.09      AU  1723089936
# 3              2.77      UY  1723089936
# 4              9.30      NO  1723089936

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          isafjordur  66.0755  -23.1240      6.61        87          97
# 1               utrik  11.2278  169.8474     28.10        78          18
# 4        sandnessjoen  66.0217   12.6316     18.29        79          96
# 5             dudinka  69.4058   86.1778     14.83        47          10
# 7              tommot  58.9564  126.2925     23.17        48           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.13      IS  1723089935
# 1              5.78      MH  1723089936
# 4              9.30      NO  1723089936
# 5              9.45      RU  1723089936
# 7              1.72      RU  1723089937

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']< 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                mount isa -20.7333  139.5000     26.87        22           0
# 3                     chui -33.6971  -53.4616      8.48        81          68
# 6        port-aux-francais -49.3500   70.2167      0.41        94         100
# 8                 lakatoro -16.0999  167.4164     24.75        65         100
# 10                 ushuaia -54.8000  -68.3000      0.81        80          75
#
#          Wind Speed Country        Date
# City_ID
# 2              3.09      AU  1723089936
# 3              2.77      UY  1723089936
# 6             11.61      TF  1723089932
# 8              6.65      VU  1723089937
# 10             1.54      AR  1723089661

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")

# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.23x + 31.25
# The r-value is: -0.6360376960612751

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.48x + 28.54
# The r-value is: 0.7971073798234094

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong relationship between latitude and maximum temperature. In the Northern Hemisphere, it is a negative correlation, while in the Southern Hemisphere, it is a positive correlation. Maximum Temperature increases as we approach the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.12x + 74.33
# The r-value is: -0.09998341536533896

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.15x + 67.15
# The r-value is: -0.11165460285093641

# %% [markdown]
# **Discussion about the linear relationship:**  There is little to no relationship between latitude and humidity based on the data available. The linear equation for each hemisphere shows a very slightly positive correlation, which implies that proximity to the equator has no bearing on humdity. The scatter points show that the data is too spread for there to be any reliable correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.33x + 64.43
# The r-value is: -0.15431226907732565

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.28x + 43.19
# The r-value is: -0.09546886497925827

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no relationship between latitude and cloudiness based on the data available. The linear equation for each hemisphere shows a positive correlation, which implies that proximity to the equator has no bearing on cloudiness. The scatter points show that the data is too spread for there to be any reliable correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.01x + 3.43
# The r-value is: -0.051694394010709514

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.01x + 3.86
# The r-value is: -0.030757029591093006

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no relationship between latitude and wind speed based on the data available. The r-value is low for both hemispheres and the scatter points show that the data is too spread for there to be any reliable correlation between latitude and wind speed.
